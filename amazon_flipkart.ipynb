# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\prajwal kutwal\Downloads\amazon_sales_dataset.csv")

# %%
df.head()
# Out:
#    order_id  order_date  product_id product_category   price  \
# 0         1  2022-04-13        2637            Books  128.75
# 1         2  2023-03-12        2300          Fashion  302.60
# 2         3  2022-09-28        3670           Sports  495.80
# 3         4  2022-04-17        2522            Books  371.95
# 4         5  2022-03-13        1717           Beauty  201.68
#
#    discount_percent  quantity_sold customer_region payment_method  rating  \
# 0                10              4   North America            UPI     3.5
# 1                20              5            Asia    Credit Card     3.7
# 2                20              2          Europe            UPI     4.4
# 3                15              4     Middle East            UPI     5.0
# 4                 0              4     Middle East            UPI     4.6
#
#    review_count  discounted_price  total_revenue
# 0           443            115.88         463.52
# 1           475            242.08        1210.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          50000 non-null  int64
#  1   order_date        50000 non-null  object
#  2   product_id        50000 non-null  int64
#  3   product_category  50000 non-null  object
#  4   price             50000 non-null  float64
#  5   discount_percent  50000 non-null  int64
#  6   quantity_sold     50000 non-null  int64
#  7   customer_region   50000 non-null  object
#  8   payment_method    50000 non-null  object
#  9   rating            50000 non-null  float64
#  10  review_count      50000 non-null  int64
#  11  discounted_price  50000 non-null  float64
#  12  total_revenue     50000 non-null  float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 5.0+ MB

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# product_id          0
# product_category    0
# price               0
# discount_percent    0
# quantity_sold       0
# customer_region     0
# payment_method      0
# rating              0
# review_count        0
# discounted_price    0
# total_revenue       0
# dtype: int64

# %%
import pandas as pd
df2 = pd.read_csv(r"C:\Users\prajwal kutwal\Downloads\flipkard.csv")

# %%
df2.head()
# Out:
#    product_id      product_name        category   brand        seller  \
# 0  FKP0000001  Adidas Ultra 664            Toys  Adidas     MegaStore
# 1  FKP0000002     LG Series 124         Fashion      LG     ValueKart
# 2  FKP0000003    Redmi Model 35          Beauty   Redmi    SmartDeals
# 3  FKP0000004  Sony Edition 769            Toys    Sony  UrbanRetails
# 4  FKP0000005    Boat Prime 291  Home & Kitchen    Boat     RetailHub
#
#   seller_city     price  discount_percent  final_price  rating  ...  weight_g  \
# 0   Hyderabad  35547.34                15     30215.24     1.9  ...   3038.23
# 1      Mumbai  30693.79                10     27624.41     3.2  ...   1921.82
# 2   Ahmedabad  51214.50                40     30728.70     4.4  ...   1143.49
# 3       Delhi  33168.49                30     23217.94     2.8  ...   3644.81
# 4        Pune  14181.34                 0     14181.34     3.7  ...    310.33
#
#    warranty_months  color      size  return_policy_days  is_returnable  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          80000 non-null  object
#  1   product_name        80000 non-null  object
#  2   category            80000 non-null  object
#  3   brand               80000 non-null  object
#  4   seller              80000 non-null  object
#  5   seller_city         80000 non-null  object
#  6   price               80000 non-null  float64
#  7   discount_percent    80000 non-null  int64
#  8   final_price         80000 non-null  float64
#  9   rating              80000 non-null  float64
#  10  review_count        80000 non-null  int64
#  11  stock_available     80000 non-null  int64
#  12  units_sold          80000 non-null  int64
#  13  listing_date        80000 non-null  object
#  14  delivery_days       80000 non-null  int64
# ...

# %%
df2.isnull().sum()
# Out:
# product_id                0
# product_name              0
# category                  0
# brand                     0
# seller                    0
# seller_city               0
# price                     0
# discount_percent          0
# final_price               0
# rating                    0
# review_count              0
# stock_available           0
# units_sold                0
# listing_date              0
# delivery_days             0
# weight_g                  0
# warranty_months           0
# color                     0
# size                  13484
# return_policy_days        0
# is_returnable             0
# payment_modes             0
# shipping_weight_g         0
# product_score             0
# seller_rating             0
# dtype: int64

# %%
df2['size'].isnull().sum()
# Out:
# np.int64(13484)

# %%
df2['size'] =df2['size'].fillna('Not Applicable')

# %%
df2['size'].isnull().sum()
# Out:
# np.int64(0)

# %%
df2['size'] = df2['size'].fillna('Not Applicable')
df2.isnull().sum()
# Out:
# product_id            0
# product_name          0
# category              0
# brand                 0
# seller                0
# seller_city           0
# price                 0
# discount_percent      0
# final_price           0
# rating                0
# review_count          0
# stock_available       0
# units_sold            0
# listing_date          0
# delivery_days         0
# weight_g              0
# warranty_months       0
# color                 0
# size                  0
# return_policy_days    0
# is_returnable         0
# payment_modes         0
# shipping_weight_g     0
# product_score         0
# seller_rating         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          50000 non-null  int64
#  1   order_date        50000 non-null  object
#  2   product_id        50000 non-null  int64
#  3   product_category  50000 non-null  object
#  4   price             50000 non-null  float64
#  5   discount_percent  50000 non-null  int64
#  6   quantity_sold     50000 non-null  int64
#  7   customer_region   50000 non-null  object
#  8   payment_method    50000 non-null  object
#  9   rating            50000 non-null  float64
#  10  review_count      50000 non-null  int64
#  11  discounted_price  50000 non-null  float64
#  12  total_revenue     50000 non-null  float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 5.0+ MB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          50000 non-null  int64
#  1   order_date        50000 non-null  datetime64[ns]
#  2   product_id        50000 non-null  int64
#  3   product_category  50000 non-null  object
#  4   price             50000 non-null  float64
#  5   discount_percent  50000 non-null  int64
#  6   quantity_sold     50000 non-null  int64
#  7   customer_region   50000 non-null  object
#  8   payment_method    50000 non-null  object
#  9   rating            50000 non-null  float64
#  10  review_count      50000 non-null  int64
#  11  discounted_price  50000 non-null  float64
#  12  total_revenue     50000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(3)
# memory usage: 5.0+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          80000 non-null  object
#  1   product_name        80000 non-null  object
#  2   category            80000 non-null  object
#  3   brand               80000 non-null  object
#  4   seller              80000 non-null  object
#  5   seller_city         80000 non-null  object
#  6   price               80000 non-null  float64
#  7   discount_percent    80000 non-null  int64
#  8   final_price         80000 non-null  float64
#  9   rating              80000 non-null  float64
#  10  review_count        80000 non-null  int64
#  11  stock_available     80000 non-null  int64
#  12  units_sold          80000 non-null  int64
#  13  listing_date        80000 non-null  object
#  14  delivery_days       80000 non-null  int64
# ...

# %%
df2['listing_date'] = pd.to_datetime(df2['listing_date'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          80000 non-null  object
#  1   product_name        80000 non-null  object
#  2   category            80000 non-null  object
#  3   brand               80000 non-null  object
#  4   seller              80000 non-null  object
#  5   seller_city         80000 non-null  object
#  6   price               80000 non-null  float64
#  7   discount_percent    80000 non-null  int64
#  8   final_price         80000 non-null  float64
#  9   rating              80000 non-null  float64
#  10  review_count        80000 non-null  int64
#  11  stock_available     80000 non-null  int64
#  12  units_sold          80000 non-null  int64
#  13  listing_date        80000 non-null  datetime64[ns]
#  14  delivery_days       80000 non-null  int64
# ...

# %%
winter = df[
    df['order_date'].dt.month.isin([11, 12, 1])
]

# %%
winter.shape
winter.head()
# Out:
#     order_id order_date  product_id product_category   price  \
# 5          6 2023-12-02        1777           Sports  385.17
# 6          7 2022-01-21        4068            Books   15.78
# 11        12 2022-11-27        3637            Books  150.19
# 14        15 2023-01-08        1051           Beauty   66.65
# 19        20 2022-11-05        3390          Fashion  428.24
#
#     discount_percent  quantity_sold customer_region    payment_method  rating  \
# 5                 30              3            Asia            Wallet     3.8
# 6                  0              5            Asia               UPI     1.6
# 11                 0              1   North America  Cash on Delivery     4.4
# 14                10              2   North America        Debit Card     4.6
# 19                30              3     Middle East            Wallet     1.2
#
#     review_count  discounted_price  total_revenue
# 5            489            269.62         808.86
# ...

# %%
winter['total_revenue'].sum()
# Out:
# np.float64(8230750.34)

# %%
winter['order_id'].nunique()
# Out:
# 12480

# %%
winter['quantity_sold'].sum()
# Out:
# np.int64(37694)

# %%
winter['discount_percent'].mean()
# Out:
# np.float64(13.330929487179487)

# %%
winter.groupby(
    'product_category'
)['total_revenue'].sum().sort_values(
    ascending=False
)
# Out:
# product_category
# Fashion           1418963.86
# Electronics       1388570.56
# Beauty            1382897.98
# Home & Kitchen    1361239.66
# Books             1342319.06
# Sports            1336759.22
# Name: total_revenue, dtype: float64

# %%
df['price'].mean()
# Out:
# np.float64(252.50726)

# %%
df2['price'].mean()
# Out:
# np.float64(30137.256453874998)

# %%
df['discount_percent'].mean()
# Out:
# np.float64(13.3407)

# %%
df2['discount_percent'].mean()
# Out:
# np.float64(21.350625)

# %%
df['rating'].mean()
# Out:
# np.float64(2.996316)

# %%
df2['rating'].mean()
# Out:
# np.float64(2.99967125)

# %%
df['review_count'].mean()
# Out:
# np.float64(249.32928)

# %%
df2['review_count'].mean()
# Out:
# np.float64(25102.249875)

# %%
df['quantity_sold'].mean()
# Out:
# np.float64(2.9994)

# %%
df2['units_sold'].mean()
# Out:
# np.float64(2507.515775)

# %%
df2['delivery_days'].mean()
# Out:
# np.float64(6.006325)

# %%
winter.shape

winter['total_revenue'].sum()

df['discount_percent'].mean()
df2['discount_percent'].mean()

df['rating'].mean()
df2['rating'].mean()
# Out:
# np.float64(2.99967125)

# %%
print("Winter Shape:", winter.shape)

print("Winter Revenue:", winter['total_revenue'].sum())

print("Amazon Discount:", df['discount_percent'].mean())
print("Flipkart Discount:", df2['discount_percent'].mean())

print("Amazon Rating:", df['rating'].mean())
print("Flipkart Rating:", df2['rating'].mean())

print("Flipkart Delivery:", df2['delivery_days'].mean())
# Out:
# Winter Shape: (12480, 13)
# Winter Revenue: 8230750.34
# Amazon Discount: 13.3407
# Flipkart Discount: 21.350625
# Amazon Rating: 2.996316
# Flipkart Rating: 2.99967125
# Flipkart Delivery: 6.006325
